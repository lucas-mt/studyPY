# %% [markdown]
# ## matplotlib.pyplot: Scatter plot
# ---

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# são gráficos essenciais para dados aleatórios, para isso basta substituir `.plot()` por `.scatter()`

# %%
from random import randint

x = [randint(1, 9) for _ in range(15)]
y = [randint(1, 9) for _ in range(15)]

plt.scatter(x, y)
plt.show()

# %% [markdown]
# o tamanho dos pontos pode ser alterando usando o argumento `s=` dentro de scatter, bastaando passar um valor

# %%
x = [randint(1, 9) for _ in range(15)]
y = [randint(1, 9) for _ in range(15)]

plt.scatter(x, y, s=100)
plt.show()

# %% [markdown]
# o argumento `s=` pode receber uma lista com tamanhos diferentes, contanto que esta lista tenha o mesmo tamanho das listas `x` e `y`, podendo, assim, personalizar o tamanho de cada marcador:

# %%
x = [randint(1, 9) for _ in range(15)]
y = [randint(1, 9) for _ in range(15)]
size = [randint(199, 999) for _ in range(15)]

plt.scatter(x, y, s=size)

plt.show()

# %% [markdown]
# para mudar a cor dos pontos, basta passar o argumento `c=` e o nome da cor:

# %%
x = [randint(1, 9) for _ in range(15)]
y = [randint(1, 9) for _ in range(15)]

plt.scatter(x, y, c='green')
plt.show()

# %% [markdown]
# o argumento `c=` pode receber uma lista de cores, contanto que essa lista seja do mesmo tamanho de das listas `x` e `y`, permitindo que cada ponto tenha uma cor única:

# %%
x = [randint(1, 9) for _ in range(15)]
y = [randint(1, 9) for _ in range(15)]
colors = [randint(1, 9) for _ in range(15)]

plt.scatter(x, y, c=colors)
plt.show()

# %% [markdown]
# abaixo do comando de plot pode ser acrecentado um comando para mostrar o que cada cor significa, por exemplo, satisfação:

# %%
x = [randint(1, 9) for _ in range(15)]
y = [randint(1, 9) for _ in range(15)]
colors = [randint(1, 9) for _ in range(15)]

plt.scatter(x, y, c=colors)
cbar = plt.colorbar()
cbar.set_label('satisfaction')

plt.show()

# %% [markdown]
# para mudar o estilo dos pontos pode ser usado o argumento `marker=` e os formatos possíveis podem ser vistos no notebook *linhas.ipynb*

# %%
x = [randint(1, 9) for _ in range(15)]
y = [randint(1, 9) for _ in range(15)]

plt.scatter(x, y, marker='+')
plt.show()

# %% [markdown]
#  argumento `edgecolor=` seguido de uma cor pinta as bordas da marcação

# %%
x = [randint(1, 9) for _ in range(15)]
y = [randint(1, 9) for _ in range(15)]

plt.scatter(x, y, edgecolor='magenta')
plt.show()

# %% [markdown]
# o argumento `alpha=` recebe um valor que tornará a coloraçã da marcação mais clara ou mais escura:

# %%
x = [randint(1, 9) for _ in range(15)]
y = [randint(1, 9) for _ in range(15)]

plt.scatter(x, y, alpha=0.25)
plt.show()

# %% [markdown]
# #### usando diferentes escalas
# ---

# %% [markdown]
# usando os comandos `plt.xscale()` e `plt.yscale()` é possível mudar a escalar de valores casos estes sejam muito grandes ou muito pequenos:

# %%
#sem mudar a escala
x = [66243315, 65278046, 89470577, 57593133, 78638814, 23025806, 54890726, 71503367, 81145945, 12118630, 57678894, 43209819, 91984050, 37599330, 97247659]
y = [24025004, 27377431, 80234761, 99849307, 50729542, 62463595, 80771235, 35566428, 91964994, 73015305, 85030441, 30731715, 91394987, 78874840, 60064544]
size = [randint(199, 999) for _ in range(15)]

plt.scatter(x, y, s=size)

plt.show()

# %% [markdown]
# assim, ficando:

# %%
#com mudança de escala
x = [66243315, 65278046, 89470577, 57593133, 78638814, 23025806, 54890726, 71503367, 81145945, 12118630, 57678894, 43209819, 91984050, 37599330, 97247659]
y = [24025004, 27377431, 80234761, 99849307, 50729542, 62463595, 80771235, 35566428, 91964994, 73015305, 85030441, 30731715, 91394987, 78874840, 60064544]
size = [randint(199, 999) for _ in range(15)]

plt.scatter(x, y, s=size)
plt.xscale('log')
plt.yscale('log')

plt.show()

# %% [markdown]
# as escalas permitidas são: 'linear', 'log', 'symlog', 'asinh', 'logit', 'function', 'functionlog'.

# %% [markdown]
# é possível, usando o parâmetro `label=`, legendar cada ponto através do tamanho:

# %%
import numpy as np

x = [66243315, 65278046, 89470577, 57593133, 78638814, 23025806, 54890726, 71503367, 81145945, 12118630, 57678894, 43209819, 91984050, 37599330, 97247659]
y = [24025004, 27377431, 80234761, 99849307, 50729542, 62463595, 80771235, 35566428, 91964994, 73015305, 85030441, 30731715, 91394987, 78874840, 60064544]
size = [randint(199, 999) for _ in range(15)]

plt.scatter(x, y, s=size, label=None)

for i in [12_000_000, 30_000_000, 50_000_000, 90_000_000]:
    plt.scatter([], [], c='gray', s=(i/250_000), label=str(i))

plt.legend(title='valores', labelspacing=1)
plt.show()

# %% [markdown]
# observe que no primeiro `plt.scatter()` foi passado os valores de x e de y normalmente, o parâmetro `s` para o tamanho dos pontos, e foi passado o parâmetro `label=`, mas este recebeu `None`. Isto cria a janela, porém não escreve nada nela, pois o que de fato aparecerá vem no loop `for` logo abaixo. Neste loop, `plt.scatter()` precisa receber os valores de x e de y, no entanto, como estes já foram passados na primeiro vez, aqui deve ser passado listas vazias, apenas para não quebrar o código, em seguida o parâmetro de cor `c=`, que é opcional, o parâmetro `s=`, este é importante, pois ele vai fazer crescer os pontos da legenda, depois é passado o parâmetro `label=` que recebe o tamanho para cada ponto. Finalmente, em `plt.legend()`, passa-se o parâmetro `title=`, que dá um título à legenda, e o parâmetro `labelspacing=`, que recebe um valor em pixels para afastar cada legenda, sem este parâmetro, os pontos da legenda se sobreporiam.

# %% [markdown]
# lembrando que gráficos do tipo scatter pode também ser feitos usando o parâmetro `linstyle=o`:

# %%
import numpy as np

x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='black');

# %% [markdown]
# neste caso, o tamanho do marcardor pode ser determinado pelo parâmetro `markersize=`:

# %%
x = [randint(1, 9) for _ in range(15)]
y = [randint(1, 9) for _ in range(15)]

plt.plot(x, y, 'o', markersize=30)
plt.show()

# %% [markdown]
# para mudar a cor do marcador, usa-se `makerfacecolor=`; para mudar a cor das bordas, usa-se `markeredgecolor=`:

# %%
x = [randint(1, 9) for _ in range(15)]
y = [randint(1, 9) for _ in range(15)]

plt.plot(x, y, 'o', markerfacecolor='grey', markeredgecolor='brown')
plt.show()

# %% [markdown]
# para mudar o tamanho do marcador, usa-se `markeredgewidth=`:

# %%
x = [randint(1, 9) for _ in range(15)]
y = [randint(1, 9) for _ in range(15)]

plt.plot(x, y, 'o', markeredgewidth=20)
plt.show()

# %% [markdown]
# lembrando que esses parâmetros servem para todos os outros tiplos de marcadores, não apenas `o`.

# %% [markdown]
# é importante observar que, desta forma, usando `.plot()` ao invés de `.scatter()`, não é possível modificar cada ponto individualmente, qualquer modificação ocorrerá em todos os pontos.

# %%
x = [randint(1, 9) for _ in range(15)]
y = [randint(1, 9) for _ in range(15)]
colors = [randint(1, 9) for _ in range(15)]

plt.plot(x, y, 'o', markerfacecolor=colors)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# ...
